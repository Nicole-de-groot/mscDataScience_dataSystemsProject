# %%
import pandas as pd

# %%
kvk = pd.read_excel("DatasetKvK01102019.xls")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-81d20047c6c0> in <module>
# ----> 1 kvk = pd.read_excel("DatasetKvK01102019.xls")
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/excel.py in read_excel(io, sheet_name, header, names, index_col, parse_cols, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skip_footer, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     348
#     349     if not isinstance(io, ExcelFile):
# --> 350         io = ExcelFile(io, engine=engine)
#     351
#     352     return io.parse(
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/excel.py in __init__(self, io, engine)
#     651         self._io = _stringify_path(io)
#     652
# --> 653         self._reader = self._engines[engine](self._io)
#     654
#     655     def __fspath__(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/excel.py in __init__(self, filepath_or_buffer)
#     422             self.book = xlrd.open_workbook(file_contents=data)
#     423         elif isinstance(filepath_or_buffer, compat.string_types):
# --> 424             self.book = xlrd.open_workbook(filepath_or_buffer)
#     425         else:
#     426             raise ValueError('Must explicitly set engine if not passing in'
#
# ~/anaconda3/lib/python3.7/site-packages/xlrd/__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     109     else:
#     110         filename = os.path.expanduser(filename)
# --> 111         with open(filename, "rb") as f:
#     112             peek = f.read(peeksz)
#     113     if peek == b"PK\x03\x04": # a ZIP file
#
# FileNotFoundError: [Errno 2] No such file or directory: 'DatasetKvK01102019.xls'

# %%
kvk.head()
# Out:
#   RGL  DOSSIER    VGNUMMER                          HN1X30  \
# 0   H  1016460  18080715.0                Falco Lines B.V.
# 1   H  1036591  15881202.0   Distr. en Container Centr. BV
# 2   H  1038431  15998142.0    Pax Bouw en Indus.serv. B.V.
# 3   H  1049319  17297222.0   Water-Land Bevrachtingen B.V.
# 4   H  1056343  17633524.0  Kl, Vrs/Opsl.bdr. Gosliga B.V.
#
#                         STRVA               PCPLVA                  STRCA  \
# 0               Ridderpoort 9  2984 BG  RIDDERKERK          Ridderpoort 9
# 1               Willemskade 1  8911 AW  LEEUWARDEN           Postbus 2739
# 2                  Neptunus 2  8448 CN  HEERENVEEN            Postbus 629
# 3  Prins Hendrikkade 3-Unit 1    8801 JK  FRANEKER            Postbus 124
# 4       Rinia van Nautaweg 12    9061 AE  GYTSJERK  Rinia van Nautaweg 12
#
#                 PCPLCA                        HN1X2X30  \
# 0  2984 BG  RIDDERKERK                Falco Lines B.V.
# 1  8901 AE  LEEUWARDEN        Distributie en Container
# 2  8440 AP  HEERENVEEN                             Pax
# 3    8800 AC  FRANEKER   Water-Land Bevrachtingen B.V.
# 4    9061 AE  GYTSJERK  Koel-, Vries- en Opslagbedrijf
#
#                         HN2X2X30  ...   PLAATS_CA NMI HFD_N_VEST  C_HOOFDACT  \
# 0                            NaN  ...  Ridderkerk   0          H       52291
# 1                   Centrum B.V.  ...  Leeuwarden   0          H       52291
# 2  Bouw en Industrieservice B.V.  ...  Heerenveen   0          H       52291
# 3                            NaN  ...    Franeker   0          H       52291
# 4                   Gosliga B.V.  ...    Gytsjerk   0          H       52102
#
#                                   VERK_ACT   NEVEN1   NEVEN2  RV IND_IM_EXP  \
# 0  Expediteurs/cargadoors/bevrachters e.d.      NaN      NaN  41         NN
# 1  Expediteurs/cargadoors/bevrachters e.d.  77399.0  77111.0  41        NaN
# 2  Expediteurs/cargadoors/bevrachters e.d.   3321.0   4941.0  41         JJ
# 3  Expediteurs/cargadoors/bevrachters e.d.      NaN      NaN  41          J
# 4                Opslag in koelhuizen e.d.  52109.0  52291.0  41        NaN
#
#                  URL
# 0  www.falcolines.nl
# 1                NaN
# 2      www.paxbis.nl
# 3  www.water-land.nl
# 4                NaN
#
# [5 rows x 38 columns]

# %%
kvk.columns.tolist()
# Out:
# ['RGL',
#  'DOSSIER',
#  'VGNUMMER',
#  'HN1X30',
#  'STRVA',
#  'PCPLVA',
#  'STRCA',
#  'PCPLCA',
#  'HN1X2X30',
#  'HN2X2X30',
#  'HN45',
#  'PCVA',
#  'PCCA',
#  'BEHKN',
#  'GEOKN',
#  'GEMK_VA',
#  'GEMK_CA',
#  'GEMNAAM',
#  'PROV',
#  'STRAAT_VA',
#  'HUISNR_VA',
#  'TOEV_VA',
#  'PC_VA',
#  'PLAATS_VA',
#  'STRAAT_CA',
#  'HUISNR_CA',
#  'TOEV_CA',
#  'PC_CA',
#  'PLAATS_CA',
#  'NMI',
#  'HFD_N_VEST',
#  'C_HOOFDACT',
#  'VERK_ACT',
#  'NEVEN1',
#  'NEVEN2',
#  'RV',
#  'IND_IM_EXP',
#  'URL']

# %%
VA = kvk[["HUISNR_VA","PC_VA"]]
VA.columns = ["HUISNR","PC"]
VA.head()
# Out:
#       HUISNR      PC
# 0          9  2984BG
# 1          1  8911AW
# 2          2  8448CN
# 3          3  8801JK
# 4         12  9061AE
# 5         14  9044NR
# 6          2  8754LD
# 7          1  8397LJ
# 8         26  8629PH
# 9          2  8855CZ
# 10         7  9206AK
# 11         6  9207HE
# 12         3  9001XW
# 13         5  9076PD
# 14        11  9288GJ
# 15        15  9205BD
# 16        13  8861NS
# 17         1  8517HA
# 18        19  8447EE
# 19         1  8501ZD
# 20         7  8861NX
# 21        25  1948ND
# 22        91  9291CE
# 23       121  8456GD
# 24        12  8746NH
# 25         7  2742RA
# 26        33  9024BD
# 27        30  9035ED
# 28        66  8621CP
# 29         6  8391AH
# ...      ...     ...
# 6499      35  5048AC
# 6500       3  3124WB
# 6501     123  1171GK
# 6502      11  5049AE
# 6503      18  1336KH
# 6504      37  1055EW
# 6505       8  4475AP
# 6506      82  3311XR
# 6507      66  1094SZ
# 6508       3  3208LA
# 6509      86  2992XC
# 6510     126  1064AZ
# 6511      96  5921GM
# 6512      18  2162CH
# 6513      11  5463XB
# 6514     332  1103EW
# 6515      57  1431GD
# 6516      49  2811SK
# 6517       3  4791RX
# 6518      28  3066GN
# 6519       3  3208KP
# 6520       5  4879AP
# 6521    1261  2153KC
# 6522      98  3344CG
# 6523      76  5015BM
# 6524      69  3067DT
# 6525      73  1106PP
# 6526       7  9206AK
# 6527      20  5341RE
# 6528     245  1171VV
#
# [6529 rows x 2 columns]

# %%
CA = kvk[["HUISNR_CA","PC_CA"]]
CA.columns = ["HUISNR","PC"]
CA.head()
# Out:
#       HUISNR      PC
# 0          9  2984BG
# 1       2739  8901AE
# 2        629  8440AP
# 3        124  8800AC
# 4         12  9061AE
# 5         14  9044NR
# 6          2  8754LD
# 7          1  8397LJ
# 8         26  8629PH
# 9          2  8855CZ
# 10         7  9206AK
# 11         6  9207HE
# 12       107  9000AC
# 13        84  9076ZP
# 14        11  9288GJ
# 15        15  9205BD
# 16        60  8860AB
# 17         1  8517HA
# 18        19  8447EE
# 19       149  8500AC
# 20         9  8860AA
# 21        25  1948ND
# 22        91  9291CE
# 23       121  8456GD
# 24        12  8746NH
# 25         7  2742RA
# 26         2  9025BR
# 27        30  9035ED
# 28        66  8621CP
# 29         6  8391AH
# ...      ...     ...
# 6499      35  5048AC
# 6500       3  3124WB
# 6501     123  1171GK
# 6502      11  5049AE
# 6503      18  1336KH
# 6504      37  1055EW
# 6505       8  4475AP
# 6506      82  3311XR
# 6507      66  1094SZ
# 6508       3  3208LA
# 6509      86  2992XC
# 6510     126  1064AZ
# 6511      96  5921GM
# 6512      18  2162CH
# 6513      11  5463XB
# 6514     332  1103EW
# 6515      57  1431GD
# 6516      49  2811SK
# 6517       3  4791RX
# 6518      28  3066GN
# 6519       3  3208KP
# 6520       5  4879AP
# 6521    1261  2153KC
# 6522      98  3344CG
# 6523      76  5015BM
# 6524      69  3067DT
# 6525      73  1106PP
# 6526       7  9206AK
# 6527      20  5341RE
# 6528     245  1171VV
#
# [6529 rows x 2 columns]

# %%
#save naar files
VA.to_csv("VA_addresses.csv")
CA.to_csv("CA_addresses.csv")
