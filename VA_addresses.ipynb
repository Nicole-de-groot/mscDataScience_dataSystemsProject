# %%
import os
import pickle

# %%
VA_addresses = "VA_addresses_dict"
if os.path.isfile(VA_addresses + ".p"):
    with open(VA_addresses + '.p', 'rb') as fp:
        VA_addresses_dict = pickle.load(fp)
else: VA_addresses_dict = {}

# %%
VA_addresses_dict
# Out:
# {'0010200000100868': ['4', '9934GD'],
#  '0010200000101596': ['5', '9934AR'],
#  '0010200000102642': ['10', '9934CK'],
#  '0010200000102643': ['10', '9934CK'],
#  '0010200000102921': ['5', '9934AR'],
#  '0010200000109073': ['25', '9936EA'],
#  '0010200000109506': ['36', '9936BK'],
#  '0010200000109610': ['14', '9936GZ'],
#  '0010200000109774': ['17', '9936BP'],
#  '0010200000112120': ['4', '9936HD'],
#  '0010200000112127': ['20', '9936TG'],
#  '0010200000112152': ['4', '9936HD'],
#  '0010200000112153': ['4', '9936HD'],
#  '0010200000112154': ['4', '9936HD'],
#  '0010200000112157': ['10', '9936HD'],
#  '0010200000112158': ['10', '9936HD'],
#  '0010200000113851': ['46', '9934RS'],
#  '0010200000114783': ['13', '9936BP'],
#  '0010200000115169': ['5', '9909BZ'],
#  '0010200000115274': ['14', '9936GZ'],
#  '0010200000115684': ['10', '9934CK'],
#  '0010200000115685': ['10', '9934CK'],
#  '0010200000115944': ['4', '9936HD'],
#  '0014200010791703': ['5', '9742LA'],
# ...
